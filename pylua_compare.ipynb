# %%
import subprocess
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["font.family"] = "Helvetica"
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
subprocess.check_output(['S4','./lua-files/PhC_slab_2d_serial.lua'])
# Out:
# b'Elapsed time for serial is 32.7174 seconds.\n'

# %%
lua_data = np.loadtxt('./data/PhC_T_lua_serial.txt', skiprows=1, delimiter='\t')
py_serial_data = np.loadtxt('./data/PhC_T_py_serial.txt', skiprows=1, delimiter='\t')
py_pl_mp_data = np.loadtxt('./data/PhC_T_py_mp.txt', skiprows=1, delimiter='\t')
py_pl_mpi_data = np.loadtxt('./data/PhC_T_py_mpi.txt', skiprows=1, delimiter='\t')

# %%
fig, ax = plt.subplots(1, 1, figsize=(6, 4))
ax.plot(lua_data[:, 0], lua_data[:, 1]+3, "r", alpha=0.5, label="lua: serial")
ax.plot(py_serial_data[:, 0], py_serial_data[:, 1]+2, "orange", alpha=0.5, label="py: serial")
ax.plot(py_pl_mp_data[:, 0], py_pl_mp_data[:, 1]+1, "g", alpha=0.5, label="py: pl mp")
ax.plot(py_pl_mpi_data[:, 0], py_pl_mpi_data[:, 1], "b", alpha=0.5, label="py: pl mpi")


ax.set_xlim(lua_data[:, 0].min(), lua_data[:, 0].max()), ax.set_ylim([0, 4])
ax.set_xlabel("Frequency (2$\pi c/a$)"), ax.set_ylabel("Transmission")
ax.legend(loc=3)
ax.grid(linestyle="--")
ax.set_title("2D PhC slab")
fig.tight_layout()
plt.show()
